# %%
import requests
import pandas as pd
import numpy as np
import datetime
from datetime import date
from datetime import datetime
from datetime import timedelta

# %%
from londonbssfront.params import *

# %% [markdown]
# ### Weather API 1

# %%
url="https://api.open-meteo.com/v1/forecast?latitude=51.5072&longitude=0.1276&current_weather=true&hourly=temperature_2m,relativehumidity_2m,windspeed_10m"

# %%
response= requests.get(url)
weather = response.json()

# %%
weather
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 weather
#
# NameError: name 'weather' is not defined

# %% [markdown]
# ### Weather API 2

# %%
url_2='http://api.weatherapi.com/v1/forecast.json'

# %%
parameters={'key':WEATHER_KEY,'q':'London','days':2}

# %%
response_2= requests.get(url_2,params=parameters)
weather_2 = response_2.json()

# %%
weather_2
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1693760688,
#   'localtime': '2023-09-03 18:04'},
#  'current': {'last_updated_epoch': 1693760400,
#   'last_updated': '2023-09-03 18:00',
#   'temp_c': 25.0,
#   'temp_f': 77.0,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 2.5,
#   'wind_kph': 4.0,
#   'wind_degree': 40,
#   'wind_dir': 'NE',
#   'pressure_mb': 1026.0,
#   'pressure_in': 30.3,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 51,
#   'cloud': 0,
#   'feelslike_c': 26.4,
#   'feelslike_f': 79.5,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 6.0,
#   'gust_mph': 8.9,
#   'gust_kph': 14.4},
#  'forecast': {'forecastday': [{'date': '2023-09-03',
#     'date_epoch': 1693699200,
#     'day': {'maxtemp_c': 25.5,
#      'maxtemp_f': 77.9,
#      'mintemp_c': 15.1,
#      'mintemp_f': 59.2,
#      'avgtemp_c': 20.0,
#      'avgtemp_f': 67.9,
#      'maxwind_mph': 6.9,
#      'maxwind_kph': 11.2,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 71.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 5.0},
#     'astro': {'sunrise': '06:15 AM',
#      'sunset': '07:43 PM',
#      'moonrise': '09:05 PM',
#      'moonset': '10:43 AM',
#      'moon_phase': 'Waning Gibbous',
#      'moon_illumination': '88',
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1693695600,
#       'time': '2023-09-03 00:00',
#       'temp_c': 16.3,
#       'temp_f': 61.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 69,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 26,
#       'feelslike_c': 16.3,
#       'feelslike_f': 61.3,
#       'windchill_c': 16.3,
#       'windchill_f': 61.3,
#       'heatindex_c': 16.3,
#       'heatindex_f': 61.3,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0},
#      {'time_epoch': 1693699200,
#       'time': '2023-09-03 01:00',
#       'temp_c': 15.9,
#       'temp_f': 60.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 81,
#       'wind_dir': 'E',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.27,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 15,
#       'feelslike_c': 15.9,
#       'feelslike_f': 60.6,
#       'windchill_c': 15.9,
#       'windchill_f': 60.6,
#       'heatindex_c': 15.9,
#       'heatindex_f': 60.6,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.2,
#       'uv': 1.0},
#      {'time_epoch': 1693702800,
#       'time': '2023-09-03 02:00',
#       'temp_c': 15.6,
#       'temp_f': 60.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 67,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.27,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 13,
#       'feelslike_c': 15.6,
#       'feelslike_f': 60.1,
#       'windchill_c': 15.6,
#       'windchill_f': 60.1,
#       'heatindex_c': 15.6,
#       'heatindex_f': 60.1,
#       'dewpoint_c': 13.3,
#       'dewpoint_f': 55.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.3,
#       'gust_kph': 10.1,
#       'uv': 1.0},
#      {'time_epoch': 1693706400,
#       'time': '2023-09-03 03:00',
#       'temp_c': 15.4,
#       'temp_f': 59.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 57,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 19,
#       'feelslike_c': 15.4,
#       'feelslike_f': 59.7,
#       'windchill_c': 15.4,
#       'windchill_f': 59.7,
#       'heatindex_c': 15.4,
#       'heatindex_f': 59.7,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0},
#      {'time_epoch': 1693710000,
#       'time': '2023-09-03 04:00',
#       'temp_c': 15.3,
#       'temp_f': 59.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 53,
#       'wind_dir': 'NE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.3,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 20,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 13.1,
#       'dewpoint_f': 55.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0},
#      {'time_epoch': 1693713600,
#       'time': '2023-09-03 05:00',
#       'temp_c': 15.1,
#       'temp_f': 59.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 67,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 22,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.2,
#       'windchill_c': 15.1,
#       'windchill_f': 59.2,
#       'heatindex_c': 15.1,
#       'heatindex_f': 59.2,
#       'dewpoint_c': 13.1,
#       'dewpoint_f': 55.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.4,
#       'uv': 1.0},
#      {'time_epoch': 1693717200,
#       'time': '2023-09-03 06:00',
#       'temp_c': 15.3,
#       'temp_f': 59.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 75,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 10,
#       'feelslike_c': 15.3,
#       'feelslike_f': 59.5,
#       'windchill_c': 15.3,
#       'windchill_f': 59.5,
#       'heatindex_c': 15.3,
#       'heatindex_f': 59.5,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 1.0},
#      {'time_epoch': 1693720800,
#       'time': '2023-09-03 07:00',
#       'temp_c': 16.6,
#       'temp_f': 61.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 89,
#       'wind_dir': 'E',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 9,
#       'feelslike_c': 16.6,
#       'feelslike_f': 61.9,
#       'windchill_c': 16.6,
#       'windchill_f': 61.9,
#       'heatindex_c': 16.6,
#       'heatindex_f': 61.9,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 5.0},
#      {'time_epoch': 1693724400,
#       'time': '2023-09-03 08:00',
#       'temp_c': 18.1,
#       'temp_f': 64.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 71,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 8,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.6,
#       'windchill_c': 18.1,
#       'windchill_f': 64.6,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.6,
#       'dewpoint_c': 14.0,
#       'dewpoint_f': 57.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 5.0},
#      {'time_epoch': 1693728000,
#       'time': '2023-09-03 09:00',
#       'temp_c': 19.6,
#       'temp_f': 67.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 85,
#       'wind_dir': 'E',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.32,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 5,
#       'feelslike_c': 19.6,
#       'feelslike_f': 67.3,
#       'windchill_c': 19.6,
#       'windchill_f': 67.3,
#       'heatindex_c': 19.6,
#       'heatindex_f': 67.3,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 5.0},
#      {'time_epoch': 1693731600,
#       'time': '2023-09-03 10:00',
#       'temp_c': 21.6,
#       'temp_f': 70.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 88,
#       'wind_dir': 'E',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.33,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 5,
#       'feelslike_c': 21.6,
#       'feelslike_f': 70.9,
#       'windchill_c': 21.6,
#       'windchill_f': 70.9,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 6.0},
#      {'time_epoch': 1693735200,
#       'time': '2023-09-03 11:00',
#       'temp_c': 23.0,
#       'temp_f': 73.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 70,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.33,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 57,
#       'cloud': 6,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 6.0},
#      {'time_epoch': 1693738800,
#       'time': '2023-09-03 12:00',
#       'temp_c': 24.2,
#       'temp_f': 75.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 93,
#       'wind_dir': 'E',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.33,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 53,
#       'cloud': 7,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.7,
#       'windchill_c': 24.2,
#       'windchill_f': 75.6,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.7,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 6.0},
#      {'time_epoch': 1693742400,
#       'time': '2023-09-03 13:00',
#       'temp_c': 25.1,
#       'temp_f': 77.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 131,
#       'wind_dir': 'SE',
#       'pressure_mb': 1027.0,
#       'pressure_in': 30.32,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 25,
#       'feelslike_c': 26.0,
#       'feelslike_f': 78.8,
#       'windchill_c': 25.1,
#       'windchill_f': 77.2,
#       'heatindex_c': 26.0,
#       'heatindex_f': 78.8,
#       'dewpoint_c': 14.4,
#       'dewpoint_f': 57.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.2,
#       'gust_kph': 3.6,
#       'uv': 7.0},
#      {'time_epoch': 1693746000,
#       'time': '2023-09-03 14:00',
#       'temp_c': 25.4,
#       'temp_f': 77.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 94,
#       'wind_dir': 'E',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 16,
#       'feelslike_c': 26.1,
#       'feelslike_f': 79.0,
#       'windchill_c': 25.4,
#       'windchill_f': 77.7,
#       'heatindex_c': 26.1,
#       'heatindex_f': 79.0,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.2,
#       'gust_kph': 3.6,
#       'uv': 7.0},
#      {'time_epoch': 1693749600,
#       'time': '2023-09-03 15:00',
#       'temp_c': 25.5,
#       'temp_f': 77.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 75,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 11,
#       'feelslike_c': 26.3,
#       'feelslike_f': 79.3,
#       'windchill_c': 25.5,
#       'windchill_f': 77.9,
#       'heatindex_c': 26.3,
#       'heatindex_f': 79.3,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 7.0},
#      {'time_epoch': 1693753200,
#       'time': '2023-09-03 16:00',
#       'temp_c': 25.4,
#       'temp_f': 77.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 79,
#       'wind_dir': 'E',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.28,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 11,
#       'feelslike_c': 26.2,
#       'feelslike_f': 79.2,
#       'windchill_c': 25.4,
#       'windchill_f': 77.7,
#       'heatindex_c': 26.2,
#       'heatindex_f': 79.2,
#       'dewpoint_c': 14.8,
#       'dewpoint_f': 58.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 7.0},
#      {'time_epoch': 1693756800,
#       'time': '2023-09-03 17:00',
#       'temp_c': 24.7,
#       'temp_f': 76.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 99,
#       'wind_dir': 'E',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.28,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 56,
#       'cloud': 16,
#       'feelslike_c': 25.8,
#       'feelslike_f': 78.4,
#       'windchill_c': 24.7,
#       'windchill_f': 76.5,
#       'heatindex_c': 25.8,
#       'heatindex_f': 78.4,
#       'dewpoint_c': 15.2,
#       'dewpoint_f': 59.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.0,
#       'gust_kph': 9.7,
#       'uv': 6.0},
#      {'time_epoch': 1693760400,
#       'time': '2023-09-03 18:00',
#       'temp_c': 25.0,
#       'temp_f': 77.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 40,
#       'wind_dir': 'NE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.3,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 0,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'dewpoint_c': 15.8,
#       'dewpoint_f': 60.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 6.0},
#      {'time_epoch': 1693764000,
#       'time': '2023-09-03 19:00',
#       'temp_c': 20.8,
#       'temp_f': 69.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 103,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 0,
#       'feelslike_c': 20.8,
#       'feelslike_f': 69.4,
#       'windchill_c': 20.8,
#       'windchill_f': 69.4,
#       'heatindex_c': 20.8,
#       'heatindex_f': 69.4,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 6.0},
#      {'time_epoch': 1693767600,
#       'time': '2023-09-03 20:00',
#       'temp_c': 20.0,
#       'temp_f': 68.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 111,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.3,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 0,
#       'feelslike_c': 20.0,
#       'feelslike_f': 68.0,
#       'windchill_c': 20.0,
#       'windchill_f': 68.0,
#       'heatindex_c': 20.0,
#       'heatindex_f': 68.0,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 1.0},
#      {'time_epoch': 1693771200,
#       'time': '2023-09-03 21:00',
#       'temp_c': 19.5,
#       'temp_f': 67.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 101,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.3,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 0,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.1,
#       'windchill_c': 19.5,
#       'windchill_f': 67.1,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.1,
#       'dewpoint_c': 15.1,
#       'dewpoint_f': 59.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0},
#      {'time_epoch': 1693774800,
#       'time': '2023-09-03 22:00',
#       'temp_c': 19.1,
#       'temp_f': 66.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 90,
#       'wind_dir': 'E',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 0,
#       'feelslike_c': 19.1,
#       'feelslike_f': 66.4,
#       'windchill_c': 19.1,
#       'windchill_f': 66.4,
#       'heatindex_c': 19.1,
#       'heatindex_f': 66.4,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.6,
#       'gust_kph': 12.2,
#       'uv': 1.0},
#      {'time_epoch': 1693778400,
#       'time': '2023-09-03 23:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 82,
#       'wind_dir': 'E',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 0,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0}]},
#    {'date': '2023-09-04',
#     'date_epoch': 1693785600,
#     'day': {'maxtemp_c': 25.6,
#      'maxtemp_f': 78.1,
#      'mintemp_c': 16.7,
#      'mintemp_f': 62.1,
#      'avgtemp_c': 20.7,
#      'avgtemp_f': 69.2,
#      'maxwind_mph': 10.3,
#      'maxwind_kph': 16.6,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 63.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 6.0},
#     'astro': {'sunrise': '06:17 AM',
#      'sunset': '07:41 PM',
#      'moonrise': '09:22 PM',
#      'moonset': '12:10 PM',
#      'moon_phase': 'Waning Gibbous',
#      'moon_illumination': '79',
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1693782000,
#       'time': '2023-09-04 00:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 84,
#       'wind_dir': 'E',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.29,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 0,
#       'feelslike_c': 18.3,
#       'feelslike_f': 64.9,
#       'windchill_c': 18.3,
#       'windchill_f': 64.9,
#       'heatindex_c': 18.3,
#       'heatindex_f': 64.9,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.5,
#       'uv': 1.0},
#      {'time_epoch': 1693785600,
#       'time': '2023-09-04 01:00',
#       'temp_c': 17.9,
#       'temp_f': 64.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 85,
#       'wind_dir': 'E',
#       'pressure_mb': 1026.0,
#       'pressure_in': 30.28,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 0,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.2,
#       'windchill_c': 17.9,
#       'windchill_f': 64.2,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.2,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.2,
#       'uv': 1.0},
#      {'time_epoch': 1693789200,
#       'time': '2023-09-04 02:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 78,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.27,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 0,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.6,
#       'gust_kph': 12.2,
#       'uv': 1.0},
#      {'time_epoch': 1693792800,
#       'time': '2023-09-04 03:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 74,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.27,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 0,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 1.0},
#      {'time_epoch': 1693796400,
#       'time': '2023-09-04 04:00',
#       'temp_c': 17.1,
#       'temp_f': 62.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 74,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.27,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 0,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.8,
#       'windchill_c': 17.1,
#       'windchill_f': 62.8,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.8,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 1.0},
#      {'time_epoch': 1693800000,
#       'time': '2023-09-04 05:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 72,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.25,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 0,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.3,
#       'gust_kph': 13.3,
#       'uv': 1.0},
#      {'time_epoch': 1693803600,
#       'time': '2023-09-04 06:00',
#       'temp_c': 16.9,
#       'temp_f': 62.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 72,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1025.0,
#       'pressure_in': 30.25,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 2,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.4,
#       'windchill_c': 16.9,
#       'windchill_f': 62.4,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.4,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 1.0},
#      {'time_epoch': 1693807200,
#       'time': '2023-09-04 07:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 74,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.25,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 5,
#       'feelslike_c': 18.4,
#       'feelslike_f': 65.1,
#       'windchill_c': 18.4,
#       'windchill_f': 65.1,
#       'heatindex_c': 18.4,
#       'heatindex_f': 65.1,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 5.0},
#      {'time_epoch': 1693810800,
#       'time': '2023-09-04 08:00',
#       'temp_c': 20.1,
#       'temp_f': 68.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 86,
#       'wind_dir': 'E',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.24,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 4,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.2,
#       'windchill_c': 20.1,
#       'windchill_f': 68.2,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.2,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.6,
#       'uv': 6.0},
#      {'time_epoch': 1693814400,
#       'time': '2023-09-04 09:00',
#       'temp_c': 22.0,
#       'temp_f': 71.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 91,
#       'wind_dir': 'E',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.24,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 58,
#       'cloud': 4,
#       'feelslike_c': 24.5,
#       'feelslike_f': 76.1,
#       'windchill_c': 22.0,
#       'windchill_f': 71.6,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 6.0},
#      {'time_epoch': 1693818000,
#       'time': '2023-09-04 10:00',
#       'temp_c': 23.6,
#       'temp_f': 74.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 91,
#       'wind_dir': 'E',
#       'pressure_mb': 1024.0,
#       'pressure_in': 30.23,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 4,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 23.6,
#       'windchill_f': 74.5,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'dewpoint_c': 12.3,
#       'dewpoint_f': 54.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.2,
#       'gust_kph': 14.8,
#       'uv': 6.0},
#      {'time_epoch': 1693821600,
#       'time': '2023-09-04 11:00',
#       'temp_c': 24.8,
#       'temp_f': 76.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 95,
#       'wind_dir': 'E',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.22,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 43,
#       'cloud': 9,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.7,
#       'windchill_c': 24.8,
#       'windchill_f': 76.6,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.7,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 6.0},
#      {'time_epoch': 1693825200,
#       'time': '2023-09-04 12:00',
#       'temp_c': 25.3,
#       'temp_f': 77.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 89,
#       'wind_dir': 'E',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.2,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 41,
#       'cloud': 7,
#       'feelslike_c': 25.6,
#       'feelslike_f': 78.1,
#       'windchill_c': 25.3,
#       'windchill_f': 77.5,
#       'heatindex_c': 25.6,
#       'heatindex_f': 78.1,
#       'dewpoint_c': 11.1,
#       'dewpoint_f': 52.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 7.0},
#      {'time_epoch': 1693828800,
#       'time': '2023-09-04 13:00',
#       'temp_c': 25.6,
#       'temp_f': 78.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 91,
#       'wind_dir': 'E',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.18,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 41,
#       'cloud': 4,
#       'feelslike_c': 25.8,
#       'feelslike_f': 78.4,
#       'windchill_c': 25.6,
#       'windchill_f': 78.1,
#       'heatindex_c': 25.8,
#       'heatindex_f': 78.4,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 7.0},
#      {'time_epoch': 1693832400,
#       'time': '2023-09-04 14:00',
#       'temp_c': 25.5,
#       'temp_f': 77.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 88,
#       'wind_dir': 'E',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.17,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 42,
#       'cloud': 0,
#       'feelslike_c': 25.9,
#       'feelslike_f': 78.6,
#       'windchill_c': 25.5,
#       'windchill_f': 77.9,
#       'heatindex_c': 25.9,
#       'heatindex_f': 78.6,
#       'dewpoint_c': 11.8,
#       'dewpoint_f': 53.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 7.0},
#      {'time_epoch': 1693836000,
#       'time': '2023-09-04 15:00',
#       'temp_c': 25.1,
#       'temp_f': 77.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 87,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 42,
#       'cloud': 0,
#       'feelslike_c': 25.6,
#       'feelslike_f': 78.1,
#       'windchill_c': 25.1,
#       'windchill_f': 77.2,
#       'heatindex_c': 25.6,
#       'heatindex_f': 78.1,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 7.0},
#      {'time_epoch': 1693839600,
#       'time': '2023-09-04 16:00',
#       'temp_c': 24.6,
#       'temp_f': 76.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 84,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 42,
#       'cloud': 0,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 24.6,
#       'windchill_f': 76.3,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 10.8,
#       'dewpoint_f': 51.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.3,
#       'uv': 6.0},
#      {'time_epoch': 1693843200,
#       'time': '2023-09-04 17:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 83,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 44,
#       'cloud': 0,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 10.4,
#       'dewpoint_f': 50.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 6.0},
#      {'time_epoch': 1693846800,
#       'time': '2023-09-04 18:00',
#       'temp_c': 21.7,
#       'temp_f': 71.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 87,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 0,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.1,
#       'windchill_c': 21.7,
#       'windchill_f': 71.1,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.9,
#       'dewpoint_c': 11.0,
#       'dewpoint_f': 51.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 6.0},
#      {'time_epoch': 1693850400,
#       'time': '2023-09-04 19:00',
#       'temp_c': 19.8,
#       'temp_f': 67.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 78,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 59,
#       'cloud': 0,
#       'feelslike_c': 19.8,
#       'feelslike_f': 67.6,
#       'windchill_c': 19.8,
#       'windchill_f': 67.6,
#       'heatindex_c': 19.8,
#       'heatindex_f': 67.6,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 5.0},
#      {'time_epoch': 1693854000,
#       'time': '2023-09-04 20:00',
#       'temp_c': 19.0,
#       'temp_f': 66.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 70,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 0,
#       'feelslike_c': 19.0,
#       'feelslike_f': 66.2,
#       'windchill_c': 19.0,
#       'windchill_f': 66.2,
#       'heatindex_c': 19.0,
#       'heatindex_f': 66.2,
#       'dewpoint_c': 12.3,
#       'dewpoint_f': 54.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 1.0},
#      {'time_epoch': 1693857600,
#       'time': '2023-09-04 21:00',
#       'temp_c': 18.6,
#       'temp_f': 65.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 68,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 68,
#       'cloud': 0,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.5,
#       'windchill_c': 18.6,
#       'windchill_f': 65.5,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.5,
#       'dewpoint_c': 12.5,
#       'dewpoint_f': 54.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 1.0},
#      {'time_epoch': 1693861200,
#       'time': '2023-09-04 22:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 66,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.13,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 0,
#       'feelslike_c': 18.3,
#       'feelslike_f': 64.9,
#       'windchill_c': 18.3,
#       'windchill_f': 64.9,
#       'heatindex_c': 18.3,
#       'heatindex_f': 64.9,
#       'dewpoint_c': 12.4,
#       'dewpoint_f': 54.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.4,
#       'uv': 1.0},
#      {'time_epoch': 1693864800,
#       'time': '2023-09-04 23:00',
#       'temp_c': 18.0,
#       'temp_f': 64.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 60,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.13,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 0,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.2,
#       'windchill_c': 17.9,
#       'windchill_f': 64.2,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.2,
#       'dewpoint_c': 12.4,
#       'dewpoint_f': 54.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 1.0}]}]}}

# %%
current=datetime.now().strftime("%Y-%m-%d %H:00")
current
# Out:
# '2023-09-03 18:00'

# %%
(datetime.now()+timedelta(hours=9)).strftime("%Y-%m-%d %H:00")
# Out:
# '2023-09-04 03:00'

# %%
for day in weather_2['forecast']['forecastday']:
    if day['date']==(datetime.now()+timedelta(hours=9)).strftime("%Y-%m-%d"):
        for hour in day['hour']:
            if hour['time']==(datetime.now()+timedelta(hours=9)).strftime("%Y-%m-%d %H:00"):
                print(hour['temp_c'])
                print(hour['condition']['text'])
                print(hour['condition']['icon'])
                print(hour['chance_of_rain'])
# Out:
# 17.4
# Clear
# //cdn.weatherapi.com/weather/64x64/night/113.png
# 0
